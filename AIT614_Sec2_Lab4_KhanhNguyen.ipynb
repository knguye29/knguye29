# %% [markdown]
# ### AIT 614 - Big Data Essentials <br>
# #### Lab 4: Spark with Python in Databricks
# <hr>
# <b>Purpose for helping students to learn PySpark for Data Science in Databricks</b><br>
#
# Created by Dr. Liao <br>
#  <hr>
# <b>Please type into your course section # and your full name:</b><br><br>
#
# Course Section #: AIT614-Sect2<br>
# Student's Full Name: Khanh Nguyen<br>
#
# <hr>
# <b>Please follow Dr. Liao's code examples/tutorials to complete these tasks:</b>

# %% [markdown]
# #### Load a data file

# %%
df = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/money4khanh@gmail.com/EmployeeAttrition.csv")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
print(df.columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
display(df.select('Gender'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ##### 1. Count the employees whose TotalWorkingYears are greater than 20.

# %%
df.filter(df.TotalWorkingYears > 20).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[74]: 207</div>

# %% [markdown]
# ##### 2. Find EmployeeNumber, EducationField, JobRole for all the employees whose Age is between 25 and 30 and Education is 5. Use display() to display EmployeeNumber, EducationField, and JobRobe only.

# %%
df_sel = df.filter((df.Age >=25) & (df.Age <= 30) & (df.Education == 5)).select(df.EmployeeNumber, df.EducationField, df.JobRole)
display(df_sel)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EmployeeNumber</th><th>EducationField</th><th>JobRole</th></tr></thead><tbody><tr><td>455</td><td>Other</td><td>Laboratory Technician</td></tr><tr><td>565</td><td>Technical Degree</td><td>Research Scientist</td></tr><tr><td>747</td><td>Marketing</td><td>Sales Executive</td></tr><tr><td>1094</td><td>Life Sciences</td><td>Laboratory Technician</td></tr></tbody></table></div>

# %% [markdown]
# ##### 3. For all the women employees having Age between 35 and 40 and TotalWorkingYears < 5, sort EmployeeNumber in an ascending order. Use display() to show EmployeeNumber and Department in the output.

# %%
df_sel1 = df.filter((df.Gender == 'Female') & (df.Age >=35) & (df.Age <= 40) & (df.TotalWorkingYears < 5)).select(df.EmployeeNumber, df.Department)

display(df_sel1.sort(df.EmployeeNumber.cast('int').asc()))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EmployeeNumber</th><th>Department</th></tr></thead><tbody><tr><td>49</td><td>Sales</td></tr><tr><td>75</td><td>Research & Development</td></tr><tr><td>245</td><td>Research & Development</td></tr><tr><td>805</td><td>Sales</td></tr><tr><td>1569</td><td>Research & Development</td></tr><tr><td>1662</td><td>Research & Development</td></tr><tr><td>1675</td><td>Research & Development</td></tr><tr><td>1886</td><td>Research & Development</td></tr><tr><td>2052</td><td>Research & Development</td></tr></tbody></table></div>

# %% [markdown]
# ##### 4. Find employees whose HourlyRate is greater than 100 or DailyRate is greater than 1490. Display Age, HourlyRate, DailyRate, and Department only and sort DailyRate in a descending order.

# %%
df_sel2 = df.filter((df.HourlyRate >100) | (df.DailyRate >1490)).select(df.Age, df.HourlyRate, df. DailyRate, df.Department)
display(df_sel2.sort(df_sel2.DailyRate.desc()))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ##### 5. For each JobRole, find the average MonthlyIncome. Print out the formatted monthly incomes in hundredth and arrange them in descending order?

# %%
from pyspark.sql.functions import avg, round
df_sel3 = df.groupBy('JobRole').agg(round(avg('MonthlyIncome'), 2).alias('avg_MonthlyIncome'))
display(df_sel3.sort('avg_MonthlyIncome', ascending=False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>JobRole</th><th>avg_MonthlyIncome</th></tr></thead><tbody><tr><td>Manager</td><td>17181.68</td></tr><tr><td>Research Director</td><td>16033.55</td></tr><tr><td>Healthcare Representative</td><td>7528.76</td></tr><tr><td>Manufacturing Director</td><td>7295.14</td></tr><tr><td>Sales Executive</td><td>6924.28</td></tr><tr><td>Human Resources</td><td>4235.75</td></tr><tr><td>Research Scientist</td><td>3239.97</td></tr><tr><td>Laboratory Technician</td><td>3237.17</td></tr><tr><td>Sales Representative</td><td>2626.0</td></tr></tbody></table></div>

# %%
df_sel3.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>JobRole</th><th>avg_MonthlyIncome</th></tr></thead><tbody><tr><td>Sales Executive</td><td>6924.28</td></tr><tr><td>Manufacturing Director</td><td>7295.14</td></tr><tr><td>Laboratory Technician</td><td>3237.17</td></tr><tr><td>Sales Representative</td><td>2626.0</td></tr><tr><td>Healthcare Representative</td><td>7528.76</td></tr><tr><td>Research Scientist</td><td>3239.97</td></tr><tr><td>Manager</td><td>17181.68</td></tr><tr><td>Research Director</td><td>16033.55</td></tr><tr><td>Human Resources</td><td>4235.75</td></tr></tbody></table></div>

# %% [markdown]
# ##### 6. Count the different MaritalStatus when Attrition is Yes and Age is greater than 35 in the dataset. Arrange the count in descending order.

# %%
df_sel4 = df.filter((df.Attrition == 'Yes') & (df.Age >35)).groupBy('MaritalStatus').count()
display(df_sel4.sort('count', ascending=False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MaritalStatus</th><th>count</th></tr></thead><tbody><tr><td>Married</td><td>33</td></tr><tr><td>Single</td><td>30</td></tr><tr><td>Divorced</td><td>14</td></tr></tbody></table></div>

# %%
display(df_sel4)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MaritalStatus</th><th>count</th></tr></thead><tbody><tr><td>Married</td><td>33</td></tr><tr><td>Divorced</td><td>14</td></tr><tr><td>Single</td><td>30</td></tr></tbody></table></div>
