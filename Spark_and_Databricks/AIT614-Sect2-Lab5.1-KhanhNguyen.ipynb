# %% [markdown]
# ### AIT 614 - Big Data Essentials <br>
# #### Lab 5.1 - Market Basket Analysis and Recommendation
# <hr>
# <b>Machine Learning using Spark MLlib on Databricks</b><br>
#
# Course Section #: AIT614-Sect2<br>
# Student's Full Name: Khanh Nguyen<br>

# %%
from pyspark.ml.fpm import FPGrowth

df = spark.createDataFrame([
    (0, [1, 2, 5]),
    (1, [1, 2, 3, 5]),
    (2, [1, 2])
], ["id", "items"])

fpGrowth = FPGrowth(itemsCol="items", minSupport=0.5, minConfidence=0.6)
model = fpGrowth.fit(df)

# Display frequent itemsets.
model.freqItemsets.show()

# Display generated association rules.
model.associationRules.show()

# transform examines the input items against all the association rules and summarize the
# consequents as prediction
model.transform(df).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----+
#     items|freq|
# +---------+----+
#       [1]|   3|
#       [2]|   3|
#    [2, 1]|   3|
#       [5]|   2|
#    [5, 2]|   2|
# [5, 2, 1]|   2|
#    [5, 1]|   2|
# +---------+----+
#
# +----------+----------+------------------+----+------------------+
# antecedent|consequent|        confidence|lift|           support|
# +----------+----------+------------------+----+------------------+
#        [5]|       [2]|               1.0| 1.0|0.6666666666666666|
#        [5]|       [1]|               1.0| 1.0|0.6666666666666666|
#     [5, 1]|       [2]|               1.0| 1.0|0.6666666666666666|
#     [5, 2]|       [1]|               1.0| 1.0|0.6666666666666666|
#        [2]|       [5]|0.6666666666666666| 1.0|0.6666666666666666|
#        [2]|       [1]|               1.0| 1.0|               1.0|
#     [2, 1]|       [5]|0.6666666666666666| 1.0|0.6666666666666666|
#        [1]|       [5]|0.6666666666666666| 1.0|0.6666666666666666|
#        [1]|       [2]|               1.0| 1.0|               1.0|
# +----------+----------+------------------+----+------------------+
#
# +---+------------+----------+
#  id|       items|prediction|
# +---+------------+----------+
#   0|   [1, 2, 5]|        []|
#   1|[1, 2, 3, 5]|        []|
#   2|      [1, 2]|       [5]|
# +---+------------+----------+
#
# </div>

# %%
#Create a training set

from pyspark.ml.fpm import FPGrowth

df_train = spark.createDataFrame([
    (0, ["apple", "orange", "eggs", "milk"]),
    (1, ["apple", "orange", "bread", "milk"]),
    (2, ["apple", "orange"]),
    (3, ["eggs", "butter", "bread"]),
    (4, ["rice", "bread", "orange", "mushroom", "tomato"]),
    (5, ["sausage", "milk", "mushroom", "tomato"]),
    (6, ["apple", "orange", "mushroom", "tomato"]),
    (7, ["butter", "bread", "milk", "mushroom", "tomato"]),
    (8, ["sausage", "bread", "butter"]),
    (9, ["butter", "bread", "apple", "sausage", "tomato"]),
    (10, ["orange", "bread", "sausage"]),
    (11, ["apple", "butter", "mushroom", "bread"]),
    (12, ["rice", "bread", "mushroom", "eggs", "orange"]),
    (13, ["eggs", "rice", "milk"]),
    (14, ["rice", "sausage"]),
    (15, ["eggs", "sausage", "rice", "apple", "orange"]),
], ["id", "items"])

df_train.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>items</th></tr></thead><tbody><tr><td>0</td><td>List(apple, orange, eggs, milk)</td></tr><tr><td>1</td><td>List(apple, orange, bread, milk)</td></tr><tr><td>2</td><td>List(apple, orange)</td></tr><tr><td>3</td><td>List(eggs, butter, bread)</td></tr><tr><td>4</td><td>List(rice, bread, orange, mushroom, tomato)</td></tr><tr><td>5</td><td>List(sausage, milk, mushroom, tomato)</td></tr><tr><td>6</td><td>List(apple, orange, mushroom, tomato)</td></tr><tr><td>7</td><td>List(butter, bread, milk, mushroom, tomato)</td></tr><tr><td>8</td><td>List(sausage, bread, butter)</td></tr><tr><td>9</td><td>List(butter, bread, apple, sausage, tomato)</td></tr><tr><td>10</td><td>List(orange, bread, sausage)</td></tr><tr><td>11</td><td>List(apple, butter, mushroom, bread)</td></tr><tr><td>12</td><td>List(rice, bread, mushroom, eggs, orange)</td></tr><tr><td>13</td><td>List(eggs, rice, milk)</td></tr><tr><td>14</td><td>List(rice, sausage)</td></tr><tr><td>15</td><td>List(eggs, sausage, rice, apple, orange)</td></tr></tbody></table></div>

# %%
#Use FP-Growth to build a model. Set different minSupport and minConfidence

fpGrowth1 = FPGrowth(itemsCol="items", minSupport=0.2, minConfidence=0.65)
model1 = fpGrowth1.fit(df_train)

# Display frequent itemsets.
model1.freqItemsets.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+----+
#              items|freq|
# +------------------+----+
#             [milk]|   5|
#            [bread]|   9|
#           [orange]|   8|
#    [orange, bread]|   4|
#             [eggs]|   5|
#            [apple]|   7|
#    [apple, orange]|   5|
#         [mushroom]|   6|
#  [mushroom, bread]|   4|
#          [sausage]|   6|
#           [butter]|   5|
#    [butter, bread]|   5|
#             [rice]|   5|
#           [tomato]|   5|
# [tomato, mushroom]|   4|
# +------------------+----+
#
# </div>

# %%
# Display generated association rules.
model1.associationRules.show()

# transform examines the input items against all the association rules and summarize the
# consequents as prediction
model1.transform(df_train).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+----------+------------------+------------------+-------+
# antecedent|consequent|        confidence|              lift|support|
# +----------+----------+------------------+------------------+-------+
#   [tomato]|[mushroom]|               0.8|2.1333333333333333|   0.25|
#    [apple]|  [orange]|0.7142857142857143|1.4285714285714286| 0.3125|
# [mushroom]|   [bread]|0.6666666666666666|1.1851851851851851|   0.25|
# [mushroom]|  [tomato]|0.6666666666666666|2.1333333333333333|   0.25|
#   [butter]|   [bread]|               1.0|1.7777777777777777| 0.3125|
# +----------+----------+------------------+------------------+-------+
#
# +---+--------------------+------------------+
#  id|               items|        prediction|
# +---+--------------------+------------------+
#   0|[apple, orange, e...|                []|
#   1|[apple, orange, b...|                []|
#   2|     [apple, orange]|                []|
#   3|[eggs, butter, br...|                []|
#   4|[rice, bread, ora...|                []|
#   5|[sausage, milk, m...|           [bread]|
#   6|[apple, orange, m...|           [bread]|
#   7|[butter, bread, m...|                []|
#   8|[sausage, bread, ...|                []|
#   9|[butter, bread, a...|[mushroom, orange]|
#  10|[orange, bread, s...|                []|
#  11|[apple, butter, m...|  [orange, tomato]|
#  12|[rice, bread, mus...|          [tomato]|
#  13|  [eggs, rice, milk]|                []|
#  14|     [rice, sausage]|                []|
#  15|[eggs, sausage, r...|                []|
# +---+--------------------+------------------+
#
# </div>

# %%
#Create a Test set
df_test = spark.createDataFrame([
    (0, ["apple", "eggs", "milk"]),
    (1, ["bread", "milk", "mushroom"]),
    (2, ["orange", "tomato"]),
    (3, ["apple", "orange", "bread"]),
    (4, ["apple", "bread", "tomato"]),
], ["id", "items"])

df_test.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>items</th></tr></thead><tbody><tr><td>0</td><td>List(apple, eggs, milk)</td></tr><tr><td>1</td><td>List(bread, milk, mushroom)</td></tr><tr><td>2</td><td>List(orange, tomato)</td></tr><tr><td>3</td><td>List(apple, orange, bread)</td></tr><tr><td>4</td><td>List(apple, bread, tomato)</td></tr></tbody></table></div>

# %%
#Make Recommendation/Prediction
model1.transform(df_test).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+--------------------+------------------+
#  id|               items|        prediction|
# +---+--------------------+------------------+
#   0| [apple, eggs, milk]|          [orange]|
#   1|[bread, milk, mus...|          [tomato]|
#   2|    [orange, tomato]|        [mushroom]|
#   3|[apple, orange, b...|                []|
#   4|[apple, bread, to...|[mushroom, orange]|
# +---+--------------------+------------------+
#
# </div>

# %% [markdown]
# ### Citation/Reference <br>
#
# Apache Spark. (2022). Frequent Pattern Mining.  Retrieved on April 6, 2022 from https://spark.apache.org/docs/latest/ml-frequent-pattern-mining.html
#
# Han J., Pei J., Yin Y. (2000). Mining frequent patterns without candidate generation. Association for Computing Machinery Publisher. Retrieved on April 6, 2022 from https://dl.acm.org/doi/10.1145/335191.335372
# <br>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#PrefixSpan: a sequential pattern mining algorithm

from pyspark.ml.fpm import PrefixSpan
from pyspark.sql import Row, SparkSession
df = sc.parallelize([Row(sequence=[[1, 2], [3]]),
                     Row(sequence=[[1], [3, 2], [1, 2]]),
                     Row(sequence=[[1, 2], [5]]),
                     Row(sequence=[[6]])]).toDF()

prefixSpan = PrefixSpan(minSupport=0.5, maxPatternLength=5,
                        maxLocalProjDBSize=32000000)

# Find frequent sequential patterns.
prefixSpan.findFrequentSequentialPatterns(df).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+----+
#   sequence|freq|
# +----------+----+
#      [[2]]|   3|
#      [[3]]|   2|
#      [[1]]|   3|
#   [[1, 2]]|   3|
# [[1], [3]]|   2|
# +----------+----+
#
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
